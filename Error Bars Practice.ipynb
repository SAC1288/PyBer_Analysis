# %%
# %matplotlib inline

# %%
#Import dependencies.
import matplotlib.pyplot as plt
import statistics

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#Next, we'll calculate the standard deviation of the y_axis values using the statistics module.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
#Next, add the x_axis, y_axis, and yerr=stdev to the errorbar function:
plt.errorbar(x_axis, y_axis, yerr=stdev)
plt.show()

# %%
#We can make the error bars look more professional by adding a "cap" to the error bars 
#that's equal to a scalar value. To do this, we use the capsize= parameter. 
#Let's add capsize=3 to the error bars. 
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
#Now that we've added error bars to the line chart, 
#we can begin to make assumptions about the plotted data.==>what kind?

# %%
#Now let's add error bars and a capsize using the object-oriented approach.

# %%
#Using object-oriented approach to produce the same data.
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
#Add Error Bars to a Bar Chart

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
#using object-oriented approach
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
#Change the Major Ticks

# %%
#When we graphed our horizontal bar chart with the fare on the x-axis, Matplotlib automatically added the ticks. 
#We can customize our charts so that the major ticks on an axis are more spread out or closer together. 
#Which one you choose depends on what the data looks like on a graph.

# %%
#To adjust the major x-axis ticks on a horizontal bar chart, we use the xticks() function.
import numpy as np
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()
plt.show()

# %%
#Alternatively, you can use ax.xaxis.set_ticks() instead of ax.set_xticks().

# %%
#To add minor ticks to the x-axis on a horizontal bar chart, we use the set_minor_locator function with the xaxis class in the object-oriented method
#Inside the set_minor_locator function, we add the MultipleLocator method and pass how often we want our minor ticks.
#we have to import the MultipleLocator method from the matplotlib.ticker function.
from matplotlib.ticker import MultipleLocator
#increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8,8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

#Create minor ticks with an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
