# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.4'

# %%
# %matplotlib inline

# %%
#Importing dependencies for matplotlib and pyplot.
import matplotlib.pyplot as plt

# %%
#Set x-axis to months of the year.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

#Set y-axis to all list of total fares - in USD - accumulated for those months.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#create the plot for the x- and y-axes.
plt.plot(x_axis, y_axis)

# %%
#creating the previous plot but with the ax.plt()
fig, ax = plt.subplots()

ax.plot(x_axis, y_axis)

# %%
#creating same plot but with new ax.plt() code.
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
#To create an even quicker object-oriented interface method, we use the following two lines of code:
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
#To change figure-level attributes (such as axis labels, a title, or a legend) or save the figure as an image, use fig = plt.figure()

# %%
#using plt.show()
plt.plot(x_axis, y_axis)
plt.show()
#plt.show() should only be used once per session because it can cause the graph to display improperly.\
# If you have problems with data not being displayed properly, you may have to restart your kernel\ 
#and clear your output.

# %%
#Note: To restart the kernel and clear the output, you will have to select "Restart & Clear Output"\
#in the Kernel tab on Jupyter Notebook

# %%
import pandas as pd

# %%
#Annotate Charts Using the MATLAB Method
#Here are a few methods that you can use to annotate charts using the MATLAB method:
matplotlib_functions_list_df = pd.DataFrame(
                              [{"plt.figure(figsize=(w, h))":"Change the size of the figure in pixels.Added on the first line of the script.",
                              "plt.plot(x, y, label='line')":"Add a label that will be added to the legend",
                              "plt.xlim(min, max)":	"Set the min and max range of the x-axis",
                              "plt.ylim(min, max)":"Set the min and max range of the y-axis.",
                              "plt.xlabel('x label')":"Add a label to the x-axis.",
                              "plt.ylabel('y label')":"Add a label to the y-axis.",
                              "plt.title('Title')":"Add a title.",
                              "plt.legend()":"Add a legend.",
                              "plt.grid()":"Add a grid to the chart",
                              "plt.savefig('add a path and figure extension')":"Save the figure with the given extension. Added at the end of the script"}])

#Note1: 'Title' in plt.title should be "Title".
#Note2: 'add a path...extension' in plt.savefig should have "" as well.

matplotlib_functions_list_df
# Out:
#                           plt.figure(figsize=(w, h))  \
# 0  Change the size of the figure in pixels.Added ...
#
#                    plt.plot(x, y, label='line')  \
# 0  Add a label that will be added to the legend
#
#                         plt.xlim(min, max)  \
# 0  Set the min and max range of the x-axis
#
#                          plt.ylim(min, max)       plt.xlabel('x label')  \
# 0  Set the min and max range of the y-axis.  Add a label to the x-axis.
#
#         plt.ylabel('y label') plt.title('Title')   plt.legend()  \
# 0  Add a label to the y-axis.       Add a title.  Add a legend.
#
#                 plt.grid()     plt.savefig('add a path and figure extension')
# 0  Add a grid to the chart  Save the figure with the given extension. Adde...

# %%
#Creating the plot again but adding labels and legend.
plt.plot(x_axis, y_axis, label="Boston")

#Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Set the y imi between 0 and 45 ==>"Why do we set the y limit?"
plt.ylim(0,45)

#Creating a title.
plt.title("Pyber Fare By Month")

#Add the legend.
plt.legend()

# %%
#Creating the plot again but with different color and marker
#Creating the plot again but adding labels and legend.
plt.plot(x_axis, y_axis, marker="*", color="green", linewidth=2, label="Boston")

#Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Set the y imi between 0 and 45 ==>"Why do we set the y limit?"
plt.ylim(0,45)

#Creating a title.
plt.title("Pyber Fare By Month")

#Add the legend.
plt.legend()

# %%
#to change the figure size to 20 pixels wide by 10 pixels high, you can do one of the following:
#1: plt.figure(figsize=(20,10))
#2: plt.subplots(figsize=(20,10))

# %%
#Note: Annotating CHarts Using the Object-Oriented Interface is similar to using the MATLAB approach, with a slightly different syntax.

# %%
#see file titled Mod 5: Matplotlib Notes.docx for table on matplotlib object-oriented functions.

# %%
#Setting new values for vertical bar chart now with the same data.

#x-axis is set to months of the year.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

#y-axis is set to total fare in US Dollars accumulated each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#creating vertical bar chart.
plt.bar(x_axis, y_axis, color ="orange", label="Boston")

#Creating labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Create a title.
plt.title("PyBer Fare by Month")

#Add the legend.
plt.legend()

# %%
#Creating Horizontal bar chart.
#Note1: If you're graphing nominal variables (e.g., favorite music groups among teens, number of votes by county or state) where you sort the data from greatest to least or least to greatest, it's best to use a horizontal bar chart.

plt.barh(x_axis, y_axis, color="magenta", label="Boston")
#To have the months in ascending order.
plt.gca().invert_yaxis()

plt.xlabel("Fare($)")
plt.ylabel("Date")

#Create a title.
plt.title("PyBer Fare by Month")

plt.legend()

# %%
#Now using object-oriented methods to create bar charts with the same ride-sharing data.

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#To create a bar chart using the object-oriented interface method, use the ax.bar() function and add the x and y data parameters inside the parentheses. 
fix, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#utilizing object-oriented emthod to create a horizontal bar chart.

fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label="Boston")

#Setting x- and y-axes.
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")

#Setting title.
ax.set_title("PyBer Fare By Month")

#Setting legend.
ax.legend()

# %%
# Set the x-axis to months of the year.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

#creating scatter plot with for the x- and y-axes.
plt.plot(x_axis, y_axis, "o")

# %%
#To create a scatter plot using the plt.scatter() function, add the x-axis and y-axis parameters 
#inside the parentheses, as shown here:

plt.scatter(x_axis, y_axis, color="red", label="Chicago")

plt.xlabel("Date")
plt.ylabel("Average Fare($)")

#Create a title.
plt.title("PyBer Fare by Month")

plt.legend()

# %%
#Now we are going to create Bubble charts
plt.scatter(x_axis, y_axis, s=y_axis, color="grey")

# %%
#Some of the markers in the previous chart lok small. Let's make them bigger so that
#the chart is mroe ligible and impactful.
#We can adjust the size by multiplying the data in the y-axis by any value. 
#Let's multiply each data point in the y-axis by 3 and see what happens. 
#To do this, we can iterate through the y-axis data and multiply each data point by 3 and 
#add it to a new list, like this:
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

y_axis_larger
# Out:
# [30.06,
#  69.72,
#  117.60000000000001,
#  106.26,
#  97.02000000000001,
#  81.12,
#  131.46,
#  31.68,
#  35.55,
#  83.69999999999999,
#  62.13,
#  60.269999999999996]

# %%
#Now use y-axis larger for the bubble chart.
plt.scatter(x_axis, y_axis, s=y_axis_larger, color="grey")

# %%
#We can refactor the code we used to create a scatter plot above, but instead of using a for loop 
#to create the list y_axis_larger for the size parameter of the marker, 
#we can use Python's list comprehension technique inside the plt.scatter() function. 
#You can use list comprehension to replace many for and while loops. 
#List comprehension is faster because it is optimized for Python to spot a predictable pattern during looping.

#The format for list comprehension is as follows.

#new_list = [expression for item in list if conditional]

# %%
#Using the list comprehension technique to multiply each data point in the y-axis list, we would do the following in the 
#plt.scatter() function:
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis], color="grey")

# %%
#Creating a scatter plot using the object-oriented interface.

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
#Now creating bubble chart with object-oriented interface.
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis, color="skyblue", label="Boston")

# %%
#Create a Pie Chart Using the MATLAB Method
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
#Let's add percentages for each month and "explode" the largest percentage, which is July, 
#the seventh value in the x_axis. The "explode" parameter will offset the indicated wedge by a 
#fraction of the radius, where "0" is zero distance from the center of the pie, and 
#"1" is completely outside the diameter of the pie.
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct="%.1f%%")
plt.show()

# %%
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct="%.1f%%")
plt.show()

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
#Create a Pie Chart Using the Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
#Now that we have learned how to create a variety of charts, 
#let's learn how to annotate charts by adding error bars and changing the major and minor ticks on the axes.

# %%
#To create a line chart with error bars using the MATLAB approach, we use the errorbar() function. We also add the x and y data parameters and the 
#yerr= parameter inside parentheses, as shown here:
#plt.errorbar(x, y, yerr=<value>)

# %%
#Plot a Pandas DataFrame and Series

# %%
#We can quickly visualize our data from a DataFrame or Series by using the plot() function by 
#adding the Series (ds) or DataFrame (df) in the following format: ds.plot() or df.plot().
